# %% [markdown]
# # Generate load + inspect /metrics

# %%
import httpx, random
for _ in range(50):
    httpx.get('http://localhost:8000/work', params={'slow_ms': random.randint(10, 250)})
print(httpx.get('http://localhost:8000/metrics').text)
